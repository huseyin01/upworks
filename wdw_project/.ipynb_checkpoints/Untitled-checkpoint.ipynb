# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Train2015-2018.csv')

# %%
#pd.set_option('display.max_columns', 900)

# %%
df['TimeOfDay'].head()
# Out:
# 0    1/1/2015 7:15
# 1    1/1/2015 7:30
# 2    1/1/2015 7:45
# 3    1/1/2015 8:00
# 4    1/1/2015 8:15
# Name: TimeOfDay, dtype: object

# %%
df.shape
# Out:
# (93123, 815)

# %%
df1=df.iloc[:1000,2:63]

# %%
df1.head()
# Out:
#    HS15  MK01  MK02  MK05  MK06  MK142  MK162  MK168  MK41  AK07  ...  MK148  \
# 0   5.0  10.0   5.0  20.0   5.0   20.0    5.0   45.0  10.0   NaN  ...    NaN
# 1   5.0  10.0   5.0  20.0   5.0   20.0   10.0   50.0  10.0   NaN  ...    NaN
# 2   5.0  10.0   5.0  25.0   5.0   20.0   10.0   60.0  10.0   5.0  ...    NaN
# 3  10.0  10.0   5.0  30.0   NaN   20.0   10.0   60.0  10.0   5.0  ...    NaN
# 4  10.0  10.0   5.0  30.0  15.0   20.0   30.0   75.0  10.0  10.0  ...    NaN
#
#    AK08  MK173  EP155  AK85  AK86  MK95  EP23  HS103  HS104
# 0   NaN    NaN    NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 1   NaN    NaN    NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 2   NaN    NaN    NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 3   NaN    NaN    NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 4   NaN    NaN    NaN   NaN   NaN   NaN   NaN    NaN    NaN
#
# [5 rows x 61 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 2))
plt.title('Relative importance of attributes')
sns.heatmap(data=df1, annot=True, fmt='.2f', cmap='RdYlGn')
plt.show()

# %%
#df_initial['InvoiceDate'] = pd.to_datetime(df_initial['InvoiceDate'])
#____________________________________________________________
# gives some infos on columns types and numer of null values

tab_info=pd.DataFrame(df.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()/df.shape[0]*100).T.
                         rename(index={0:'null values (%)'}))
display(tab_info)
# Out:
#                     date TimeOfDay     HS15     MK01     MK02     MK05  \
# column type       object    object  float64  float64  float64  float64
# null values (nb)       0         0    20770    13565    11701    10538
# null values (%)        0         0  22.3038  14.5668  12.5651  11.3162
#
#                      MK06    MK142    MK162    MK168  ... EPHOURS_REL2  \
# column type       float64  float64  float64  float64  ...      float64
# null values (nb)    12754    11769    64167    62832  ...            0
# null values (%)   13.6959  12.6381  68.9056  67.4721  ...            0
#
#                  EPHOURS_REL3 HSHOURS_REL HSHOURS_REL1 HSHOURS_REL2  \
# column type           float64     float64      float64      float64
# null values (nb)            0           0            0            0
# null values (%)             0           0            0            0
#
#                  HSHOURS_REL3 AKHOURS_REL AKHOURS_REL1 AKHOURS_REL2  \
# ...

# %%
for i in df.columns:
    if (df[i].isnull().sum()/df[i].shape[0]*100) > 0.9:
        print(i)
    else:
        continue
# Out:
# HS15
# MK01
# MK02
# MK05
# MK06
# MK142
# MK162
# MK168
# MK41
# AK07
# AK11
# AK18
# AK20
# EP02
# EP04
# EP07
# EP09
# EP53
# HS03
# HS20
# MK04
# MK141
# AK14
# HS12
# MK13
# EP14
# EP16
# EP19
# HS22
# MK03
# MK23
# MK16
# EP18
# AK10
# EP06
# AK43
# AK16
# HS24
# MK33
# AK22
# HS05
# MK133
# MK159
# MK18
# AK17
# HS89
# HS93
# EP153
# EP11
# MK135
# HS64
# MK148
# AK08
# MK173
# EP155
# AK85
# AK86
# MK95
# EP23
# HS103
# HS104
# WDWEVENTS
# WDWPRICEFACTOR
# WDWTICKETSEASON
# HSFIREN
# AKFIREN
# MKFIRET2
# EPFIRET2
# HSFIRET1
# HSFIRET2
# HSPRDDN
# AKPRDDN
# MKPRDDT2
# HSPRDDT1
# AKPRDDT1
# AKPRDDT2
# MKPRDNN
# MKPRDNT1
# MKPRDNT2
# AKSHWNN
# HSSHWNT2
# AKSHWNT1
# AKSHWNT2
# AKeventN
# EPeventN
# HSeventN
# MKeventN
# WDWRaceN
# WDWeventN
# HOLIDAYN
# HOLIDAYJ
# MKHSOPHOURS
# GDP_USA
# GDP_USA_prev1
# GDP_USA_prev2
# GDP_USA_prev3
# EMP_USA
# EMP_USA_prev1
# EMP_USA_prev2
# EMP_USA_prev3
# EMP_USA_prev4
# EMP_USA_prev5
# EMP_USA_prev6
# GDP_USA_prev4
# GDP_USA_prev5
# ...

# %%
print(tab_info)
# Out:
#                     date TimeOfDay     HS15     MK01     MK02     MK05  \
# column type       object    object  float64  float64  float64  float64
# null values (nb)       0         0    20770    13565    11701    10538
# null values (%)        0         0  22.3038  14.5668  12.5651  11.3162
#
#                      MK06    MK142    MK162    MK168  ... EPHOURS_REL2  \
# column type       float64  float64  float64  float64  ...      float64
# null values (nb)    12754    11769    64167    62832  ...            0
# null values (%)   13.6959  12.6381  68.9056  67.4721  ...            0
#
#                  EPHOURS_REL3 HSHOURS_REL HSHOURS_REL1 HSHOURS_REL2  \
# column type           float64     float64      float64      float64
# null values (nb)            0           0            0            0
# null values (%)             0           0            0            0
#
#                  HSHOURS_REL3 AKHOURS_REL AKHOURS_REL1 AKHOURS_REL2  \
# ...

# %%
df.iloc[:,2:63].isnull().sum()
# Out:
# HS15     20770
# MK01     13565
# MK02     11701
# MK05     10538
# MK06     12754
# MK142    11769
# MK162    64167
# MK168    62832
# MK41     52852
# AK07     27561
# AK11     28378
# AK18     33970
# AK20     29870
# EP02     21479
# EP04     21239
# EP07     30654
# EP09     27526
# EP53     83413
# HS03     49154
# HS20     24321
# MK04     23451
# MK141    12965
# AK14     37797
# HS12     24581
# MK13     18195
# EP14     27920
# EP16     24350
# EP19     65224
# HS22     22665
# MK03     20124
#          ...
# MK16     21903
# EP18     92040
# AK10     93006
# EP06     92082
# AK43     93071
# AK16     93114
# HS24     75141
# MK33     93073
# AK22     93081
# HS05     93082
# MK133    93076
# MK159    93089
# MK18     92816
# AK17     92811
# HS89     65425
# HS93     93030
# EP153    65737
# EP11     93115
# MK135    92658
# HS64     74022
# MK148    70476
# AK08     93003
# MK173    72034
# EP155    49391
# AK85     62828
# AK86     62397
# MK95     93110
# ...

# %%
sns.heatmap(df.iloc[:,2:63].isnull(), cbar=False)

# %%
sns.heatmap(df.isnull(), cbar=False)

# %%
sns.set(rc={'figure.figsize':(17, 4)})

# %%
df['HS22'].plot(linewidth=0.5);

# %%
df1 = df.set_index(['TimeOfDay'], drop=True)

# %%
df1.head()
# Out:
#                    date  HS15  MK01  MK02  MK05  MK06  MK142  MK162  MK168  \
# TimeOfDay
# 1/1/2015 7:15  1/1/2015   5.0  10.0   5.0  20.0   5.0   20.0    5.0   45.0
# 1/1/2015 7:30  1/1/2015   5.0  10.0   5.0  20.0   5.0   20.0   10.0   50.0
# 1/1/2015 7:45  1/1/2015   5.0  10.0   5.0  25.0   5.0   20.0   10.0   60.0
# 1/1/2015 8:00  1/1/2015  10.0  10.0   5.0  30.0   NaN   20.0   10.0   60.0
# 1/1/2015 8:15  1/1/2015  10.0  10.0   5.0  30.0  15.0   20.0   30.0   75.0
#
#                MK41  ...  EPHOURS_REL2  EPHOURS_REL3  HSHOURS_REL  \
# TimeOfDay            ...
# 1/1/2015 7:15  10.0  ...          0.92          0.94         1.02
# 1/1/2015 7:30  10.0  ...          0.92          0.94         1.02
# 1/1/2015 7:45  10.0  ...          0.92          0.94         1.02
# 1/1/2015 8:00  10.0  ...          0.92          0.94         1.02
# 1/1/2015 8:15  10.0  ...          0.92          0.94         1.02
#
#                HSHOURS_REL1  HSHOURS_REL2  HSHOURS_REL3  AKHOURS_REL  \
# ...

# %%
df['HS22'].plot(linewidth=0.5);

# %%
df['TimeOfDay'].dtypes
# Out:
# dtype('O')

# %%
df.iloc[:,0:5].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93123 entries, 0 to 93122
# Data columns (total 5 columns):
# date         93123 non-null object
# TimeOfDay    93123 non-null object
# HS15         72353 non-null float64
# MK01         79558 non-null float64
# MK02         81422 non-null float64
# dtypes: float64(3), object(2)
# memory usage: 3.6+ MB

# %%
print(df['TimeOfDay'].dtypes)
# Out:
# object

# %%
df2=df.copy()

# %%
df2['TimeOfDay'] = pd.to_datetime(df['TimeOfDay'])

# %%
print(df2['TimeOfDay'].dtypes)
# Out:
# datetime64[ns]

# %%
df2 = df2.set_index(['TimeOfDay'], drop=True)

# %%
df2['HS22'].plot(linewidth=0.5);

# %%
df['EP19'].plot(linewidth=0.5);

# %%
len(df['EP19'].value_counts())
# Out:
# 2

# %%
df['EP19'].isnull().sum()/df['EP19'].shape
# Out:
# array([0.70040699])

# %%
dict_= {}
for i in df.columns:
    if len(df[i].value_counts()) <= 5:
        print(i)
    else: continue
# Out:
# MK41
# EP53
# EP19
# EP06
# AK43
# AK16
# HS24
# MK33
# AK22
# HS05
# MK133
# MK159
# MK18
# AK17
# HS89
# HS93
# EP11
# MK135
# AK08
# MK95
# EP23
# YEAR
# HOLIDAY
# WDWTICKETSEASON
# MKEMHOPEN
# EPEMHOPEN
# HSEMHOPEN
# AKEMHOPEN
# MKOPEN
# EPFWOPEN
# EPWSOPEN
# HSOPEN
# AKOPEN
# MKEMHETOM
# EPEMHETOM
# HSEMHETOM
# AKEMHETOM
# MKEMHEVE
# EPEMHEVE
# HSEMHEVE
# AKEMHEVE
# MKEMHEYEST
# EPEMHEYEST
# HSEMHEYEST
# AKEMHEYEST
# MKEMHMORN
# EPEMHMORN
# HSEMHMORN
# AKEMHMORN
# MKEMHMTOM
# EPEMHMTOM
# HSEMHMTOM
# AKEMHMTOM
# MKEMHMYEST
# EPEMHMYEST
# HSEMHMYEST
# AKEMHMYEST
# EPFIREN
# AKFIREN
# MKFIRET2
# EPFIRET2
# HSFIRET2
# MKFIREWK
# EPFIREWK
# HSFIREWK
# HSFIREWKS
# MKPRDDAY
# HSPRDDAY
# AKPRDDAY
# MKPRDDN
# HSPRDDN
# AKPRDDN
# MKPRDDT1
# MKPRDDT2
# HSPRDDT1
# AKPRDDT1
# AKPRDDT2
# MKPRDNGT
# MKPRDNN
# HSSHWNGT
# AKSHWNGT
# HSSHWNN
# AKSHWNN
# HSNEWSTARTOURS
# MKOPENYEST
# EPOPENYEST
# HSOPENYEST
# AKOPENYEST
# MKOPENTOM
# EPOPENTOM
# HSOPENTOM
# AKOPENTOM
# inSession_New_Jersey
# ...

# %%
df.columns
# Out:
# Index(['date', 'TimeOfDay', 'HS15', 'MK01', 'MK02', 'MK05', 'MK06', 'MK142',
#        'MK162', 'MK168',
#        ...
#        'EPHOURS_REL2', 'EPHOURS_REL3', 'HSHOURS_REL', 'HSHOURS_REL1',
#        'HSHOURS_REL2', 'HSHOURS_REL3', 'AKHOURS_REL', 'AKHOURS_REL1',
#        'AKHOURS_REL2', 'AKHOURS_REL3'],
#       dtype='object', length=815)

# %%
plt.figure(figsize=(8, 2))
plt.title('Relative importance of attributes')
sns.heatmap(data=df.iloc[:,687:795], annot=True, fmt='.2f', cmap='RdYlGn')
plt.show()
